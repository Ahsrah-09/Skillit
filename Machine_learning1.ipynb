# %%
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;
from pandas import DataFrame,Series

# %%
import pandas as pd;
from sklearn.linear_model import LogisticRegression

# %%
iris_df=pd.read_csv("/content/Iris.csv")
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
X = iris_df.drop(  columns = ["Id","Species"] ) #all dependent columns in one variable so,dropping species column
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
Y = iris_df["Species"]
Y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
model = LogisticRegression()

# %% [markdown]
# **Training the data while passing the dependent data and independent data**

# %%
model.fit( X.values , Y )
# Out:
# LogisticRegression()

# %%
model.predict([[6,2.2,5,1.5]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
model.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model.predict([[7,3.2,4.7,1.4]])
# Out:
# array(['Iris-versicolor'], dtype=object)
